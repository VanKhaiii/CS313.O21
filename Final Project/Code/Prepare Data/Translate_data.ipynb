# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.2.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2024.4.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 20.5 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.3 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.6 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 9.9 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=068909f6c5d6e1530706c8c3014b1b8d127996b23086d33772b6d6f15ee42e22
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.4.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
import polars as pl
from tqdm import tqdm
import os

# %%
from googletrans import Translator
translator = Translator()

# %% [markdown]
# # Util functions

# %%
def translate_str_column(df, col, batch_size=200):
    texts = df[col]
    trans_texts = []

    for i in tqdm(range(0, df.shape[0], batch_size)):
        texts_batch = list(texts[i: i + batch_size])
        trans_batch = translator.translate(texts_batch, dest='vi')
        trans_batch = [trans.text.lower() for trans in trans_batch]
        trans_texts.extend(trans_batch)

    assert len(trans_texts) == df.shape[0]

    df = df.with_columns(pl.Series(name=f"{col}_trans", values=trans_texts))

    return df

def translate_cate_column(df, col, batch_size=200):
    # Strip texts
    df = df.with_columns(pl.col(col).str.strip())

    # Get all categories
    categories = set(df[col])

    if None in categories:
        categories.remove(None)

    if '' in categories:
        categories.remove('')

    categories = list(categories)

    # Dịch thể loại và tạo mapping
    mapping = {None: None, '': ''}

    for i in tqdm(range(0, len(categories), batch_size)):
        batch_cates = categories[i : i + batch_size]
        trans_cates = translator.translate(batch_cates, dest='vi')
        trans_cates = [trans.text.lower() for trans in trans_cates]
        assert len(batch_cates) == len(trans_cates)

        for j in range(len(batch_cates)):
            mapping[batch_cates[j]] = trans_cates[j]

    # Ánh xạ tiếng Trung qua tiếng Việt
    df = df.with_columns(pl.col(col).map_elements(lambda x: mapping[x]))

    return df

def translate_cate_list_column(df, col, batch_size=500):
    # Strip texts
    df = df.with_columns(pl.col(col).list.eval(pl.element().str.strip()))

    # Lưu các thể loại
    categories = {cate for row_cates in df[col] for cate in row_cates}

    if None in categories:
        categories.remove(None)

    if '' in categories:
        categories.remove('')

    categories = list(categories)

    # Dịch thể loại và tạo mapping
    mapping = {None: None, '': ''}

    for i in tqdm(range(0, len(categories), batch_size)):
        batch_cates = categories[i : i + batch_size]
        trans_cates = translator.translate(batch_cates, dest='vi')
        trans_cates = [trans.text.lower() for trans in trans_cates]
        assert len(batch_cates) == len(trans_cates)

        for j in range(len(batch_cates)):
            mapping[batch_cates[j]] = trans_cates[j]

    # Ánh xạ tiếng Trung qua tiếng Việt
    df = df.with_columns(pl.col(col).map_elements(lambda row_cates: [mapping[cate] for cate in row_cates]))

    return df

# %% [markdown]
# # Translation

# %%
RAW_DIR = '/content/drive/MyDrive/Colab Notebooks/Nhom_4/2. Thực Hành/Visualize Data/Data'
TRANS_DIR = '/content/drive/MyDrive/Colab Notebooks/Nhom_4/2. Thực Hành/Visualize Data/Translated Data'

# %% [markdown]
# ## 1. Course

# %%
course_df = pl.read_ndjson('entities/course.json')
course_df.head()
# Out:
# shape: (5, 6)
# ┌──────────┬─────────────────┬─────────────────┬───────────────┬─────────────────┬─────────────────┐
# │ id       ┆ name            ┆ field           ┆ prerequisites ┆ about           ┆ resource        │
# │ ---      ┆ ---             ┆ ---             ┆ ---           ┆ ---             ┆ ---             │
# │ str      ┆ str             ┆ list[str]       ┆ str           ┆ str             ┆ list[struct[3]] │
# ╞══════════╪═════════════════╪═════════════════╪═══════════════╪═════════════════╪═════════════════╡
# │ C_584313 ┆ 《资治通鉴》导  ┆ ["历史学",      ┆               ┆ 通过老师导读，  ┆ [{["第一课 导论 │
# │          ┆ 读              ┆ "中国语言文学"] ┆               ┆ 同学们可深入这  ┆ 与三家分晋",    │
# │          ┆                 ┆                 ┆               ┆ 一经典文本内部  ┆ "导论",         │
# │          ┆                 ┆                 ┆               ┆ ，得以纵览千年  ┆ "导论"],"V…     │
# │          ┆                 ┆                 ┆               ┆ 历史，提…       ┆                 │
# │ C_584329 ┆ 微积分——极限理  ┆ ["应用经济学",  ┆               ┆ 本课程是理工科  ┆ [{["序言",      │
# │          ┆ 论与一元函数    ┆ "数学", …       ┆               ┆ 的一门数学基础  ┆ "序言", "序言"] │
# │          ┆                 ┆ "理论经济学"]   ┆               ┆ 课，系统、全面  ┆ ,"V_1350","1…   │
# │          ┆                 ┆                 ┆               ┆ 地介绍了一元函  ┆                 │
# │          ┆                 ┆                 ┆               ┆ 数微积分…       ┆                 │
# │ C_584381 ┆ 新闻摄影        ┆ ["艺术学",      ┆               ┆ 掌握基本的摄影  ┆ [{["第一章      │
# │          ┆                 ┆ "新闻传播学"]   ┆               ┆ 技能，了解图片  ┆ 绪论", "第一讲  │
# │          ┆                 ┆                 ┆               ┆ 新闻的工作方式  ┆ 引言1",         │
# │          ┆                 ┆                 ┆               ┆ ，训练对生活的  ┆ "引言1"],"…     │
# │          ┆                 ┆                 ┆               ┆ 观察和热…       ┆                 │
# │ C_597208 ┆ 数据挖掘：理论  ┆ ["计算机科学与  ┆               ┆ 最有趣的理论+最 ┆ [{["走进数据科  │
# │          ┆ 与算法          ┆ 技术"]          ┆               ┆ 有用的算法=不得 ┆ 学：博大精深，  │
# │          ┆                 ┆                 ┆               ┆ 不学的数据科学  ┆ 美不胜收",      │
# │          ┆                 ┆                 ┆               ┆ 。              ┆ "整装待发", "…  │
# │ C_597225 ┆ 大学计算机      ┆ []              ┆               ┆ 大学计算机课程  ┆ [{["第1周： 基  │
# │          ┆                 ┆                 ┆               ┆ 将以计算思维为  ┆ 于计算机的问题  │
# │          ┆                 ┆                 ┆               ┆ 导向，以计算机  ┆ 求解",          │
# │          ┆                 ┆                 ┆               ┆ 原理、概念为基  ┆ "课程介绍",     │
# │          ┆                 ┆                 ┆               ┆ 础，以新…       ┆ "开…            │
# └──────────┴─────────────────┴─────────────────┴───────────────┴─────────────────┴─────────────────┘

# %%
course_df = translate_str_column(course_df, 'name')
course_df = translate_str_column(course_df, 'about')
course_df = translate_cate_list_column(course_df, 'field')
# Out:
# 100%|██████████| 19/19 [02:51<00:00,  9.03s/it]
# 100%|██████████| 19/19 [06:45<00:00, 21.34s/it]
# <ipython-input-8-2d5e1d4c7ae2>:51: DeprecationWarning: `strip` is deprecated. It has been renamed to `strip_chars`.
#   df = df.with_columns(pl.col(col).list.eval(pl.element().str.strip()))
# 100%|██████████| 1/1 [00:03<00:00,  3.83s/it]

# %%
course_df
# Out:
# shape: (3_781, 8)
# ┌───────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ id        ┆ name       ┆ field      ┆ prerequisi ┆ about     ┆ resource  ┆ name_tran ┆ about_tra │
# │ ---       ┆ ---        ┆ ---        ┆ tes        ┆ ---       ┆ ---       ┆ s         ┆ ns        │
# │ str       ┆ str        ┆ list[str]  ┆ ---        ┆ str       ┆ list[stru ┆ ---       ┆ ---       │
# │           ┆            ┆            ┆ str        ┆           ┆ ct[3]]    ┆ str       ┆ str       │
# ╞═══════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ C_584313  ┆ 《资治通鉴 ┆ ["lịch     ┆            ┆ 通过老师  ┆ [{["第一  ┆ giới      ┆ thông qua │
# │           ┆ 》导读     ┆ sử",       ┆            ┆ 导读，同  ┆ 课 导论与 ┆ thiệu về  ┆ sự hướng  │
# │           ┆            ┆ "trường    ┆            ┆ 学们可深  ┆ 三家分晋" ┆ zi zhi    ┆ dẫn của   │
# │           ┆            ┆ dạy tiếng  ┆            ┆ 入这一经  ┆ , "导论", ┆ tong jian ┆ giáo …    │
# │           ┆            ┆ tr…        ┆            ┆ 典文本内  ┆ "导论"]," ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 部，得以  ┆ V…        ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 纵览千年  ┆           ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 历史，提… ┆           ┆           ┆           │
# │ C_584329  ┆ 微积分——极 ┆ ["kinh tế  ┆            ┆ 本课程是  ┆ [{["序言" ┆ giải tích ┆ khóa học  │
# │           ┆ 限理论与一 ┆ học ứng    ┆            ┆ 理工科的  ┆ , "序言", ┆ - lý      ┆ này là    │
# │           ┆ 元函数     ┆ dụng",     ┆            ┆ 一门数学  ┆ "序言"]," ┆ thuyết    ┆ một khóa  │
# │           ┆            ┆ "toán h…   ┆            ┆ 基础课，  ┆ V_1350"," ┆ giới hạn  ┆ học toá…  │
# │           ┆            ┆            ┆            ┆ 系统、全  ┆ 1…        ┆ v…        ┆           │
# │           ┆            ┆            ┆            ┆ 面地介绍  ┆           ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 了一元函  ┆           ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 数微积分… ┆           ┆           ┆           │
# │ C_584381  ┆ 新闻摄影   ┆ ["nghệ     ┆            ┆ 掌握基本  ┆ [{["第一  ┆ chụp ảnh  ┆ nắm vững  │
# │           ┆            ┆ thuật",    ┆            ┆ 的摄影技  ┆ 章 绪论", ┆ tin tức   ┆ các kỹ    │
# │           ┆            ┆ "báo chí"] ┆            ┆ 能，了解  ┆ "第一讲   ┆           ┆ năng chụp │
# │           ┆            ┆            ┆            ┆ 图片新闻  ┆ 引言1",   ┆           ┆ ảnh cơ…   │
# │           ┆            ┆            ┆            ┆ 的工作方  ┆ "引言1"], ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 式，训练  ┆ "…        ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 对生活的  ┆           ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 观察和热… ┆           ┆           ┆           │
# │ C_597208  ┆ 数据挖掘： ┆ ["khoa học ┆            ┆ 最有趣的  ┆ [{["走进  ┆ khai thác ┆ lý thuyết │
# │           ┆ 理论与算法 ┆ và công    ┆            ┆ 理论+最有 ┆ 数据科学  ┆ dữ liệu:  ┆ thú vị    │
# │           ┆            ┆ nghệ máy   ┆            ┆ 用的算法= ┆ ：博大精  ┆ lý thuyết ┆ nhất +    │
# │           ┆            ┆ tính…      ┆            ┆ 不得不学  ┆ 深，美不  ┆ và …      ┆ thuật to… │
# │           ┆            ┆            ┆            ┆ 的数据科  ┆ 胜收",    ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 学。      ┆ "整装待发 ┆           ┆           │
# │           ┆            ┆            ┆            ┆           ┆ ", "…     ┆           ┆           │
# │ …         ┆ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         │
# │ C_2341259 ┆ （疾风计划 ┆ []         ┆            ┆ 疾风计划2 ┆ [{["第一  ┆ (dự án    ┆ project   │
# │           ┆ ）面向对象 ┆            ┆            ┆ 021【首期 ┆ 讲 课程简 ┆ gió) lập  ┆ blast     │
# │           ┆ 程序设计（ ┆            ┆            ┆ 限额招募  ┆ 介与编程  ┆ trình     ┆ 2021      │
# │           ┆ C++）      ┆            ┆            ┆ 】进行中  ┆ 环境",    ┆ hướng đối ┆ [tuyển    │
# │           ┆            ┆            ┆            ┆ 名校名师  ┆ "1.0 课程 ┆ …         ┆ dụng g…   │
# │           ┆            ┆            ┆            ┆ 丨专属助  ┆ 定位、教  ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 教丨专业… ┆ 学…       ┆           ┆           │
# │ C_2337996 ┆ （疾风计划 ┆ []         ┆            ┆ 疾风计划2 ┆ [{["第零  ┆ (dự án    ┆ project   │
# │           ┆ ）数据结构 ┆            ┆            ┆ 021【首期 ┆ 章  ",    ┆ gió) cấu  ┆ blast     │
# │           ┆ (下)       ┆            ┆            ┆ 限额招募  ┆ "选课之前 ┆ trúc dữ   ┆ 2021      │
# │           ┆            ┆            ┆            ┆ 】进行中  ┆ ", "宣传  ┆ liệu (ph… ┆ [tuyển    │
# │           ┆            ┆            ┆            ┆ 名校名师  ┆ 片"],"V_8 ┆           ┆ dụng g…   │
# │           ┆            ┆            ┆            ┆ 丨专属助  ┆ 7…        ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 教丨专业… ┆           ┆           ┆           │
# │ C_1945689 ┆ 机器学习训 ┆ []         ┆            ┆ 清华张敏  ┆ [{["序-开 ┆ chương    ┆ giáo viên │
# │           ┆ 练营       ┆            ┆            ┆ 老师带你1 ┆ 营仪式及  ┆ trình đào ┆ zhang min │
# │           ┆            ┆            ┆            ┆ 2周掌握机 ┆ 学习课件" ┆ tạo về    ┆ từ đại    │
# │           ┆            ┆            ┆            ┆ 器学习！8 ┆ , null,   ┆ máy học   ┆ học t…    │
# │           ┆            ┆            ┆            ┆ 大经典算  ┆ "1.1_初识 ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 法        ┆ 机…       ┆           ┆           │
# │           ┆            ┆            ┆            ┆ +7大实训  ┆           ┆           ┆           │
# │           ┆            ┆            ┆            ┆ +…        ┆           ┆           ┆           │
# │ C_2329163 ┆ 创意写作实 ┆ []         ┆ 基础写作知 ┆ 《创意写  ┆ [{["第一  ┆ hướng dẫn ┆ "hướng    │
# │           ┆ 践教程     ┆            ┆ 识，传播学 ┆ 作案例实  ┆ 章  文学  ┆ thực hành ┆ dẫn thực  │
# │           ┆            ┆            ┆ 知识，美学 ┆ 践教程》  ┆ 类实践写  ┆ viết sáng ┆ hành các  │
# │           ┆            ┆            ┆ 知识等。   ┆ 是新文科  ┆ 作", "1.1 ┆ tạ…       ┆ tình hu…  │
# │           ┆            ┆            ┆            ┆ 建设中的  ┆ 怎样写好  ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 重要学科  ┆ 一首格…   ┆           ┆           │
# │           ┆            ┆            ┆            ┆ ，其目的  ┆           ┆           ┆           │
# │           ┆            ┆            ┆            ┆ 是培养具… ┆           ┆           ┆           │
# └───────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %%
course_df.write_ndjson(os.path.join(TRANS_DIR, 'entities/course.json'))

# %% [markdown]
# ## 2. Field

# %%
course_field_df = pl.read_ndjson(os.path.join(RAW_DIR, 'relations/course-field.json'))
course_field_df.head(5)
# Out:
# shape: (5, 3)
# ┌───────────┬──────────────────────┬────────────────────────────┐
# │ course_id ┆ course_name          ┆ field                      │
# │ ---       ┆ ---                  ┆ ---                        │
# │ i64       ┆ str                  ┆ list[str]                  │
# ╞═══════════╪══════════════════════╪════════════════════════════╡
# │ 584313    ┆ 《资治通鉴》导读     ┆ ["中国语言文学", "历史学"] │
# │ 681932    ┆ “做中学”Java程序设计 ┆ ["计算机科学与技术"]       │
# │ 674962    ┆ 《红楼梦》的空间艺术 ┆ ["中国语言文学"]           │
# │ 682709    ┆ 《纯粹理性批判》导论 ┆ ["哲学"]                   │
# │ 682635    ┆ 《统万城》导读       ┆ ["历史学"]                 │
# └───────────┴──────────────────────┴────────────────────────────┘

# %%
course_field_df = translate_str_column(course_field_df, 'course_name')
course_field_df = translate_cate_list_column(course_field_df, 'field')
course_field_df.write_ndjson(os.path.join(TRANS_DIR, 'relations/course-field.json'))
# Out:
# 100%|██████████| 4/4 [00:29<00:00,  7.49s/it]
# <ipython-input-8-2d5e1d4c7ae2>:51: DeprecationWarning: `strip` is deprecated. It has been renamed to `strip_chars`.
#   df = df.with_columns(pl.col(col).list.eval(pl.element().str.strip()))
# 100%|██████████| 1/1 [00:03<00:00,  3.67s/it]

# %% [markdown]
# # 3. Concept

# %%
concept_df = pl.read_ndjson(os.path.join(RAW_DIR, 'entities/concept.json'))
concept_df.head(5)
# Out:
# shape: (5, 3)
# ┌───────────────────────────────────┬──────────────────┬───────────────────────────────────┐
# │ id                                ┆ name             ┆ context                           │
# │ ---                               ┆ ---              ┆ ---                               │
# │ str                               ┆ str              ┆ list[str]                         │
# ╞═══════════════════════════════════╪══════════════════╪═══════════════════════════════════╡
# │ K_神经部_组织学与胚胎学           ┆ 神经部           ┆ []                                │
# │ K_促甲状腺激素细胞_组织学与胚胎学 ┆ 促甲状腺激素细胞 ┆ ["质和髓质两部分组成              │
# │                                   ┆                  ┆ 答案：B                           │
# │                                   ┆                  ┆ 13．腺垂体嗜酸性细胞可分为        │
# │                                   ┆                  ┆ …                                 │
# │ K_嗜色细胞_组织学与胚胎学         ┆ 嗜色细胞         ┆ []                                │
# │ K_生长激素细胞_组织学与胚胎学     ┆ 生长激素细胞     ┆ ["案：B                           │
# │                                   ┆                  ┆ 13．腺垂体嗜酸性细胞可分为        │
# │                                   ┆                  ┆ A．催乳激素细胞、促肾…            │
# │ K_褐铁矿_材料科学与工程           ┆ 褐铁矿           ┆ ["                                │
# │                                   ┆                  ┆ 褐铁矿（Limonite）是一种常见的铁  │
# │                                   ┆                  ┆ 矿，常形成于铁矿床…               │
# └───────────────────────────────────┴──────────────────┴───────────────────────────────────┘

# %%
concept_df.shape
# Out:
# (637572, 3)

# %%
concept_df = translate_str_column(concept_df, 'name', 1000)
concept_df.write_ndjson(os.path.join(TRANS_DIR, 'entities/concept.json'))
# Out:
#   0%|          | 1/638 [02:41<28:34:42, 161.51s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-03949e18b01e> in <cell line: 1>()
# ----> 1 concept_df = translate_str_column(concept_df, 'name', 1000)
#       2 concept_df.write_ndjson(os.path.join(TRANS_DIR, 'entities/concept.json'))
#
# <ipython-input-8-2d5e1d4c7ae2> in translate_str_column(df, col, batch_size)
#       5     for i in tqdm(range(0, df.shape[0], batch_size)):
#       6         texts_batch = list(texts[i: i + batch_size])
# ----> 7         trans_batch = translator.translate(texts_batch, dest='vi')
#       8         trans_batch = [trans.text.lower() for trans in trans_batch]
#       9         trans_texts.extend(trans_batch)
#
# /usr/local/lib/python3.10/dist-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     203             result = []
#     204             for item in text:
# --> 205                 translated = self.translate(item, dest=dest, src=src, **kwargs)
#     206                 result.append(translated)
#     207             return result
#
# /usr/local/lib/python3.10/dist-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     208
#     209         origin = text
# --> 210         data, response = self._translate(text, dest, src, kwargs)
#     211
#     212         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.10/dist-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#     106
#     107         url = urls.TRANSLATE.format(host=self._pick_service_url())
# --> 108         r = self.client.get(url, params=params)
#     109
#     110         if r.status_code == 200:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in get(self, url, params, headers, cookies, auth, allow_redirects, timeout)
#     753         timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     754     ) -> Response:
# --> 755         return self.request(
#     756             "GET",
#     757             url,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     598             cookies=cookies,
#     599         )
# --> 600         return self.send(
#     601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     618         auth = self.build_auth(request, auth)
#     619
# --> 620         response = self.send_handling_redirects(
#     621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     645                 raise TooManyRedirects()
#     646
# --> 647             response = self.send_handling_auth(
#     648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send_single_request(self, request, timeout)
#     712                 headers,
#     713                 stream,
# --> 714             ) = transport.request(
#     715                 request.method.encode(),
#     716                 request.url.raw,
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in request(self, method, url, headers, stream, timeout)
#     138                 # on the same connection.
#     139                 logger.trace("get_connection_from_pool=%r", origin)
# --> 140                 connection = self._get_connection_from_pool(origin)
#     141
#     142                 if connection is None:
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in _get_connection_from_pool(self, origin)
#     207         # Close any dropped connections.
#     208         for connection in connections_to_close:
# --> 209             connection.close()
#     210
#     211         return reuse_connection
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection.py in close(self)
#     131         with self.request_lock:
#     132             if self.connection is not None:
# --> 133                 self.connection.close()
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http2.py in close(self)
#     166             self.state = ConnectionState.CLOSED
#     167
# --> 168             self.socket.close()
#     169
#     170     def wait_for_outgoing_flow(self, stream_id: int, timeout: TimeoutDict) -> int:
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_backends/sync.py in close(self)
#      76         with self.write_lock:
#      77             with map_exceptions({socket.error: CloseError}):
# ---> 78                 self.sock.close()
#      79
#      80     def is_connection_dropped(self) -> bool:
#
# /usr/lib/python3.10/socket.py in close(self)
#     500         self._closed = True
#     501         if self._io_refs <= 0:
# --> 502             self._real_close()
#     503
#     504     def detach(self):
#
# /usr/lib/python3.10/ssl.py in _real_close(self)
#    1360     def _real_close(self):
#    1361         self._sslobj = None
# -> 1362         super()._real_close()
#    1363
#    1364     @_sslcopydoc
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. School

# %%
school_df = pl.read_ndjson(os.path.join(RAW_DIR, 'entities/school.json'))
school_df.head(5)
# Out:
# shape: (5, 6)
# ┌─────┬──────────┬─────────────────────┬──────┬───────────────────────────┬────────────────────────┐
# │ id  ┆ name     ┆ name_en             ┆ sign ┆ about                     ┆ motto                  │
# │ --- ┆ ---      ┆ ---                 ┆ ---  ┆ ---                       ┆ ---                    │
# │ str ┆ str      ┆ str                 ┆ str  ┆ str                       ┆ str                    │
# ╞═════╪══════════╪═════════════════════╪══════╪═══════════════════════════╪════════════════════════╡
# │ S_1 ┆ 清华大学 ┆ Tsinghua University ┆ thu  ┆ 简称“清华”，由中华人民共  ┆ 自强不息,厚德载物      │
# │     ┆          ┆                     ┆      ┆ 和国教育部直属，中央直管  ┆                        │
# │     ┆          ┆                     ┆      ┆ 副部级建制，位…           ┆                        │
# │ S_2 ┆ 北京大学 ┆ Peking University   ┆ PKU  ┆ 北京大学（Peking Universi ┆ 博学、审问、慎思、明辨 │
# │     ┆          ┆                     ┆      ┆ ty），简称“北大”，是…     ┆                        │
# │ S_3 ┆ 武汉大学 ┆ Wuhan University    ┆ whu  ┆ 武汉大学（Wuhan Universit ┆ 自强 弘毅 求是 拓新    │
# │     ┆          ┆                     ┆      ┆ y）简称“武大”，是中华…    ┆                        │
# │ S_4 ┆ 苏州大学 ┆ Soochow University  ┆ suda ┆ 苏州大学（Soochow Univers ┆ 养天地正气，法古今完人 │
# │     ┆          ┆                     ┆      ┆ ity），坐落于历史文化…    ┆                        │
# │ S_5 ┆ 四川大学 ┆ Sichuan University  ┆ scu  ┆ 四川大学（Sichuan Univers ┆                        │
# │     ┆          ┆                     ┆      ┆ ity），简称“川大”，…      ┆                        │
# └─────┴──────────┴─────────────────────┴──────┴───────────────────────────┴────────────────────────┘

# %%
school_df.shape
# Out:
# (429, 6)

# %%
school_df = translate_str_column(school_df, 'about')
school_df = translate_str_column(school_df, 'motto')
school_df.write_ndjson(os.path.join(TRANS_DIR, 'entities/school.json'))
# Out:
# 100%|██████████| 3/3 [01:43<00:00, 34.64s/it]
# 100%|██████████| 3/3 [00:32<00:00, 10.74s/it]

# %% [markdown]
# ## 5. Teacher

# %%
teacher_df = pl.read_ndjson(os.path.join(RAW_DIR, 'entities/teacher.json'))
teacher_df.head(5)
# Out:
# shape: (5, 6)
# ┌─────┬────────┬───────────────┬───────────────────────────────────┬───────────┬──────────┐
# │ id  ┆ name   ┆ name_en       ┆ about                             ┆ job_title ┆ org_name │
# │ --- ┆ ---    ┆ ---           ┆ ---                               ┆ ---       ┆ ---      │
# │ str ┆ str    ┆ str           ┆ str                               ┆ str       ┆ str      │
# ╞═════╪════════╪═══════════════╪═══════════════════════════════════╪═══════════╪══════════╡
# │ T_1 ┆ 刘燕妮 ┆ Yanni Liu     ┆ 北大哲学系毕业，清华大学马克思主  ┆ 讲师      ┆ 清华大学 │
# │     ┆        ┆               ┆ 义学院讲师。开设过的课程，马克思… ┆           ┆          │
# │ T_2 ┆ 陈怡   ┆ Yi Chen       ┆ 1945年生于重庆，1967年华中工学院  ┆ 教授      ┆ 清华大学 │
# │     ┆        ┆               ┆ （现华中科技大学）发配电…         ┆           ┆          │
# │ T_3 ┆ 程钢   ┆ Gang Cheng    ┆ 程钢，《庄子哲学导读》课程负责人  ┆ 副教授    ┆ 清华大学 │
# │     ┆        ┆               ┆ ，清华大学历史系副教授，清华大学… ┆           ┆          │
# │ T_4 ┆ 谢维和 ┆ null          ┆ 谢维和，博士、教授、博士生导师、  ┆ 教授      ┆ 清华大学 │
# │     ┆        ┆               ┆ 教育研究院院长。研究方向：教育学… ┆           ┆          │
# │ T_5 ┆ 史静寰 ┆ Jing-huan Shi ┆ 史静寰，女，清华大学教育研究院教  ┆ 教授      ┆ 清华大学 │
# │     ┆        ┆               ┆ 授、博士生导师、清华大学第12届…   ┆           ┆          │
# └─────┴────────┴───────────────┴───────────────────────────────────┴───────────┴──────────┘

# %%
teacher_df.shape
# Out:
# (17018, 6)

# %%
# teacher_df = translate_cate_column(teacher_df, 'job_title')
# teacher_df = translate_cate_column(teacher_df, 'org_name')
teacher_df = translate_str_column(teacher_df, 'about')
teacher_df.write_ndjson(os.path.join(TRANS_DIR, 'entities/teacher.json'))
# Out:
# 100%|██████████| 86/86 [41:37<00:00, 29.04s/it]

# %%
teacher_df
# Out:
# shape: (17_018, 7)
# ┌─────────┬────────┬─────────────┬─────────────────┬─────────────┬────────────────┬────────────────┐
# │ id      ┆ name   ┆ name_en     ┆ about           ┆ job_title   ┆ org_name       ┆ about_trans    │
# │ ---     ┆ ---    ┆ ---         ┆ ---             ┆ ---         ┆ ---            ┆ ---            │
# │ str     ┆ str    ┆ str         ┆ str             ┆ str         ┆ str            ┆ str            │
# ╞═════════╪════════╪═════════════╪═════════════════╪═════════════╪════════════════╪════════════════╡
# │ T_1     ┆ 刘燕妮 ┆ Yanni Liu   ┆ 北大哲学系毕业  ┆ giảng viên  ┆ đại học thanh  ┆ tốt nghiệp     │
# │         ┆        ┆             ┆ ，清华大学马克  ┆             ┆ hoa            ┆ khoa triết học │
# │         ┆        ┆             ┆ 思主义学院讲师  ┆             ┆                ┆ của đạ…        │
# │         ┆        ┆             ┆ 。开设过的课程  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ ，马克思…       ┆             ┆                ┆                │
# │ T_2     ┆ 陈怡   ┆ Yi Chen     ┆ 1945年生于重庆  ┆ giáo sư     ┆ đại học thanh  ┆ sinh năm 1945  │
# │         ┆        ┆             ┆ ，1967年华中工  ┆             ┆ hoa            ┆ tại trùng      │
# │         ┆        ┆             ┆ 学院（现华中科  ┆             ┆                ┆ khánh, ô…      │
# │         ┆        ┆             ┆ 技大学）发配电… ┆             ┆                ┆                │
# │ T_3     ┆ 程钢   ┆ Gang Cheng  ┆ 程钢，《庄子哲  ┆ phó giáo sư ┆ đại học thanh  ┆ cheng gang là  │
# │         ┆        ┆             ┆ 学导读》课程负  ┆             ┆ hoa            ┆ người chủ trì  │
# │         ┆        ┆             ┆ 责人，清华大学  ┆             ┆                ┆ khóa…          │
# │         ┆        ┆             ┆ 历史系副教授，  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ 清华大学…       ┆             ┆                ┆                │
# │ T_4     ┆ 谢维和 ┆ null        ┆ 谢维和，博士、  ┆ giáo sư     ┆ đại học thanh  ┆ xie weihe,     │
# │         ┆        ┆             ┆ 教授、博士生导  ┆             ┆ hoa            ┆ tiến sĩ, giáo  │
# │         ┆        ┆             ┆ 师、教育研究院  ┆             ┆                ┆ sư, ngư…       │
# │         ┆        ┆             ┆ 院长。研究方向  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ ：教育学…       ┆             ┆                ┆                │
# │ …       ┆ …      ┆ …           ┆ …               ┆ …           ┆ …              ┆ …              │
# │ T_17154 ┆ 王建新 ┆             ┆ 王建新，男，法  ┆ phó giáo sư ┆ đại học công   ┆ wang jianxin,  │
# │         ┆        ┆             ┆ 学博士，中国人  ┆             ┆ an nhân dân    ┆ nam, tiến sĩ   │
# │         ┆        ┆             ┆ 民公安大学治安  ┆             ┆ trung q…       ┆ luật,…         │
# │         ┆        ┆             ┆ 学院副教授，硕  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ 士研究生…       ┆             ┆                ┆                │
# │ T_17155 ┆ 刘晓栋 ┆             ┆ 刘晓栋，男，博  ┆ giảng viên  ┆ đại học công   ┆ liu xiaodong,  │
# │         ┆        ┆             ┆ 士，硕士生导师  ┆             ┆ an nhân dân    ┆ nam, tiến sĩ,  │
# │         ┆        ┆             ┆ ，中国人民公安  ┆             ┆ trung q…       ┆ giản…          │
# │         ┆        ┆             ┆ 大学治安学院讲  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ 师，研究…       ┆             ┆                ┆                │
# │ T_17156 ┆ 何钊   ┆ hezhao      ┆ 《云南特色民间  ┆ trợ giảng   ┆ đại học nghệ   ┆ giảng viên     │
# │         ┆        ┆             ┆ 工艺》课程主讲  ┆             ┆ thuật vân nam  ┆ khóa học “thủ  │
# │         ┆        ┆             ┆ 教师。          ┆             ┆                ┆ công dâ…       │
# │         ┆        ┆             ┆ 云南艺术学院设  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ 计学院产品设计… ┆             ┆                ┆                │
# │ T_17157 ┆ 白春明 ┆ baichunming ┆ 《云南特色民间  ┆ giảng viên  ┆ đại học nghệ   ┆ giảng viên     │
# │         ┆        ┆             ┆ 工艺》课程主讲  ┆             ┆ thuật vân nam  ┆ khóa học “thủ  │
# │         ┆        ┆             ┆ 教师，云南艺术  ┆             ┆                ┆ công dâ…       │
# │         ┆        ┆             ┆ 学院设计学院产  ┆             ┆                ┆                │
# │         ┆        ┆             ┆ 品设计专…       ┆             ┆                ┆                │
# └─────────┴────────┴─────────────┴─────────────────┴─────────────┴────────────────┴────────────────┘

# %% [markdown]
# ## 6. User

# %%
user_df = pl.read_ndjson(os.path.join(RAW_DIR, 'entities/user.json'))
user_df.head(5)
# Out:
# shape: (5, 7)
# ┌──────┬────────┬────────┬──────────┬───────────────┬───────────────────────┬──────────────────────┐
# │ id   ┆ name   ┆ gender ┆ school   ┆ year_of_birth ┆ course_order          ┆ enroll_time          │
# │ ---  ┆ ---    ┆ ---    ┆ ---      ┆ ---           ┆ ---                   ┆ ---                  │
# │ str  ┆ str    ┆ i64    ┆ str      ┆ str           ┆ list[i64]             ┆ list[str]            │
# ╞══════╪════════╪════════╪══════════╪═══════════════╪═══════════════════════╪══════════════════════╡
# │ U_22 ┆ 我     ┆ 0      ┆          ┆ null          ┆ [682129, 2294668]     ┆ ["2019-10-12         │
# │      ┆        ┆        ┆          ┆               ┆                       ┆ 10:28:02", "2020-11… │
# │ U_24 ┆ 王帅国 ┆ 1      ┆ 清华大学 ┆ null          ┆ [597214, 605512, …    ┆ ["2019-05-20         │
# │      ┆        ┆        ┆          ┆               ┆ 2229905]              ┆ 16:06:48", "2019-05… │
# │ U_25 ┆ 王帅国 ┆ 0      ┆ 清华大学 ┆ null          ┆ [1903985]             ┆ ["2020-08-07         │
# │      ┆        ┆        ┆          ┆               ┆                       ┆ 18:59:13"]           │
# │ U_53 ┆ 于歆杰 ┆ 1      ┆ 清华大学 ┆ null          ┆ [696679, 1704639, …   ┆ ["2020-03-01         │
# │      ┆        ┆        ┆          ┆               ┆ 1794464]              ┆ 21:24:30", "2020-03… │
# │ U_54 ┆ 马昱春 ┆ 2      ┆ 清华大学 ┆ null          ┆ [682442, 682164, …    ┆ ["2019-10-09         │
# │      ┆        ┆        ┆          ┆               ┆ 1906706]              ┆ 02:17:49", "2019-11… │
# └──────┴────────┴────────┴──────────┴───────────────┴───────────────────────┴──────────────────────┘

# %%
user_list_df = pl.read_csv('/content/drive/MyDrive/Colab Notebooks/Nhom_4/2. Thực Hành/Visualize Data/Model Data/user_list.txt', separator=' ')
user_list_df.head()
# Out:
# shape: (5, 2)
# ┌────────┬──────────┐
# │ org_id ┆ remap_id │
# │ ---    ┆ ---      │
# │ str    ┆ i64      │
# ╞════════╪══════════╡
# │ U_146  ┆ 0        │
# │ U_185  ┆ 1        │
# │ U_205  ┆ 2        │
# │ U_217  ┆ 3        │
# │ U_464  ┆ 4        │
# └────────┴──────────┘

# %%
org_ids = user_list_df['org_id'].to_list()
len(org_ids)
# Out:
# 136860

# %%
filtered_user_df = user_df.filter(pl.col('id').is_in(org_ids))
filtered_user_df.head()
# Out:
# shape: (5, 7)
# ┌───────┬─────────────┬────────┬──────────────┬───────────────┬──────────────┬──────────────┐
# │ id    ┆ name        ┆ gender ┆ school       ┆ year_of_birth ┆ course_order ┆ enroll_time  │
# │ ---   ┆ ---         ┆ ---    ┆ ---          ┆ ---           ┆ ---          ┆ ---          │
# │ str   ┆ str         ┆ i64    ┆ str          ┆ str           ┆ list[i64]    ┆ list[str]    │
# ╞═══════╪═════════════╪════════╪══════════════╪═══════════════╪══════════════╪══════════════╡
# │ U_146 ┆ 张幸福      ┆ 1      ┆              ┆ null          ┆ [680824,     ┆ ["2020-02-03 │
# │       ┆             ┆        ┆              ┆               ┆ 766203, …    ┆ 22:03:21",   │
# │       ┆             ┆        ┆              ┆               ┆ 680845]      ┆ "2020-02…    │
# │ U_185 ┆ 教师-陈燕秀 ┆ 2      ┆ 贵州理工学院 ┆ null          ┆ [696729,     ┆ ["2019-09-18 │
# │       ┆             ┆        ┆              ┆               ┆ 707096, …    ┆ 10:13:50",   │
# │       ┆             ┆        ┆              ┆               ┆ 734053]      ┆ "2019-11…    │
# │ U_205 ┆ 尹亮        ┆ 1      ┆ 青海大学     ┆ null          ┆ [948435,     ┆ ["2020-01-02 │
# │       ┆             ┆        ┆              ┆               ┆ 735362, …    ┆ 08:48:14",   │
# │       ┆             ┆        ┆              ┆               ┆ 948296]      ┆ "2020-01…    │
# │ U_217 ┆ 饲猫少年    ┆ 0      ┆ 加利盾分校   ┆ null          ┆ [697748,     ┆ ["2020-02-07 │
# │       ┆             ┆        ┆              ┆               ┆ 883345, …    ┆ 11:50:27",   │
# │       ┆             ┆        ┆              ┆               ┆ 696685]      ┆ "2020-02…    │
# │ U_464 ┆ 教师-安宇   ┆ 1      ┆ 清华大学     ┆ null          ┆ [697069,     ┆ ["2019-09-19 │
# │       ┆             ┆        ┆              ┆               ┆ 696700, …    ┆ 10:05:10",   │
# │       ┆             ┆        ┆              ┆               ┆ 1795810]     ┆ "2019-09…    │
# └───────┴─────────────┴────────┴──────────────┴───────────────┴──────────────┴──────────────┘

# %%
filtered_user_df = translate_str_column(filtered_user_df, 'name')
filtered_user_df = translate_str_column(filtered_user_df, 'school')
filtered_user_df.write_ndjson(os.path.join(TRANS_DIR, 'entities/khai_user.json'))
# Out:
#  43%|████▎     | 214/500 [1:49:51<1:41:34, 21.31s/it]
